# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('../logs/dma_prof_w_pipeline.log') as f:
    data_w_pipeline = np.array(eval(f.readlines()[0]))

# %%
plt.plot([i[0] for i in data_w_pipeline], [i[1] for i in data_w_pipeline])

# %%
with open('../logs/dma_prof_wo_pipeline.log') as f:
    data_wo_pipeline = np.array(eval(f.readlines()[0]))
plt.plot([i[0] for i in data_wo_pipeline], [i[1] for i in data_wo_pipeline])
